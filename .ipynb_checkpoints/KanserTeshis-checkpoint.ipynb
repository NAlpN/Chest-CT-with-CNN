# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Dense,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
import matplotlib.pyplot as plt
import cv2 as cv
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
from keras.utils import to_categorical

import os

# %%
train_path_str = 'Data/train'
val_path_str = 'Data/valid'
test_path_str = 'Data/test'

# %%
test_classes = os.listdir(test_path_str)

# %%
input_shape = (224,224,3)
num_classes = 4

trainGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    rotation_range = 10,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    shear_range = 0.2,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    dtype = 'float32'
)
valGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

testGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

# %%
train_data = trainGenertor.flow_from_directory(
    train_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

val_data = valGenertor.flow_from_directory(
    val_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

test_data = testGenertor.flow_from_directory(
    test_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
VGG16_model = VGG16(
    include_top = False,
    weights="imagenet",
    input_shape = input_shape
)
for layer in VGG16_model.layers :
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 8s 0us/step

# %%
from keras.src.metrics.confusion_metrics import activations
model = Sequential()
model.add(VGG16_model)
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256,activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (Batch  (None, 7, 7, 512)         2048
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 3, 3, 512)         0
#  D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1024)              4719616
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 20125892 (76.77 MB)
# Trainable params: 5410180 (20.64 MB)
# Non-trainable params: 14715712 (56.14 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']
)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint('model.h5',save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='logs')
]

# %%
results = model.fit(train_data,validation_data=val_data,epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 57s 1s/step - loss: 1.7184 - accuracy: 0.4046 - val_loss: 1.3075 - val_accuracy: 0.5139
# Epoch 2/100
# 39/39 [==============================] - 59s 2s/step - loss: 1.1998 - accuracy: 0.4747 - val_loss: 1.0851 - val_accuracy: 0.4028
# Epoch 3/100
# 39/39 [==============================] - 54s 1s/step - loss: 1.0669 - accuracy: 0.5171 - val_loss: 1.1907 - val_accuracy: 0.3889
# Epoch 4/100
# 39/39 [==============================] - 52s 1s/step - loss: 0.9932 - accuracy: 0.5253 - val_loss: 1.1401 - val_accuracy: 0.4861
# Epoch 5/100
# 39/39 [==============================] - 52s 1s/step - loss: 0.8858 - accuracy: 0.6020 - val_loss: 0.8958 - val_accuracy: 0.5000
# Epoch 6/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.8638 - accuracy: 0.6232 - val_loss: 0.9665 - val_accuracy: 0.5694
# Epoch 7/100
# 39/39 [==============================] - 56s 1s/step - loss: 0.8726 - accuracy: 0.6085 - val_loss: 0.9692 - val_accuracy: 0.4722
# Epoch 8/100
# 39/39 [==============================] - 61s 2s/step - loss: 0.8108 - accuracy: 0.6509 - val_loss: 0.9705 - val_accuracy: 0.5000
# Epoch 9/100
# 39/39 [==============================] - 61s 2s/step - loss: 0.7048 - accuracy: 0.6754 - val_loss: 1.0420 - val_accuracy: 0.5417
# Epoch 10/100
# 39/39 [==============================] - 65s 2s/step - loss: 0.6847 - accuracy: 0.7015 - val_loss: 0.9054 - val_accuracy: 0.5833
# Epoch 11/100
# 39/39 [==============================] - 62s 2s/step - loss: 0.7159 - accuracy: 0.7096 - val_loss: 0.8469 - val_accuracy: 0.6111
# Epoch 12/100
100
# 39/39 [==============================] - 57s 1s/step - loss: 0.3197 - accuracy: 0.9021 - val_loss: 0.6603 - val_accuracy: 0.7917
# Epoch 78/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.1845 - accuracy: 0.9315 - val_loss: 0.7439 - val_accuracy: 0.7778
# Epoch 79/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2178 - accuracy: 0.9168 - val_loss: 0.6458 - val_accuracy: 0.8611
# Epoch 80/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2733 - accuracy: 0.9103 - val_loss: 0.6098 - val_accuracy: 0.8750
# Epoch 81/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2317 - accuracy: 0.9103 - val_loss: 0.5953 - val_accuracy: 0.8472
# Epoch 82/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2054 - accuracy: 0.9250 - val_loss: 0.7697 - val_accuracy: 0.8750
# Epoch 83/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2226 - accuracy: 0.9152 - val_loss: 0.7050 - val_accuracy: 0.8472
# Epoch 84/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.1696 - accuracy: 0.9299 - val_loss: 0.7384 - val_accuracy: 0.8472
# Epoch 85/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2750 - accuracy: 0.9135 - val_loss: 0.5033 - val_accuracy: 0.8333
# Epoch 86/100
# 39/39 [==============================] - 56s 1s/step - loss: 0.2117 - accuracy: 0.9266 - val_loss: 0.6922 - val_accuracy: 0.8611
# Epoch 87/100
# 39/39 [==============================] - 56s 1s/step - loss: 0.2391 - accuracy: 0.9201 - val_loss: 0.5293 - val_accuracy: 0.8750
# Epoch 88/100
# 39/39 [==============================] - 56s 1s/step - loss: 0.2087 - accuracy: 0.9217 - val_loss: 0.6911 - val_accuracy: 0.8333
# Epoch 89/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2455 - accuracy: 0.9054 - val_loss: 0.5556 - val_accuracy: 0.8611
# Epoch 90/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2242 - accuracy: 0.9201 - val_loss: 0.5640 - val_accuracy: 0.8611
# Epoch 91/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.1795 - accuracy: 0.9445 - val_loss: 0.5510 - val_accuracy: 0.8611
# Epoch 92/100
# 39/39 [==============================] - 61s 2s/step - loss: 0.1938 - accuracy: 0.9315 - val_loss: 0.6134 - val_accuracy: 0.8750
# Epoch 93/100
# 39/39 [==============================] - 66s 2s/step - loss: 0.1802 - accuracy: 0.9347 - val_loss: 0.5557 - val_accuracy: 0.8750
# Epoch 94/100
# 39/39 [==============================] - 67s 2s/step - loss: 0.1502 - accuracy: 0.9380 - val_loss: 0.4694 - val_accuracy: 0.8611
# Epoch 95/100
# 39/39 [==============================] - 64s 2s/step - loss: 0.1992 - accuracy: 0.9380 - val_loss: 0.6676 - val_accuracy: 0.8472
# Epoch 96/100
# 39/39 [==============================] - 62s 2s/step - loss: 0.2292 - accuracy: 0.9103 - val_loss: 0.8800 - val_accuracy: 0.7778
# Epoch 97/100
# 39/39 [==============================] - 60s 2s/step - loss: 0.1995 - accuracy: 0.9347 - val_loss: 0.6082 - val_accuracy: 0.8472
# Epoch 98/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.1946 - accuracy: 0.9266 - val_loss: 0.7111 - val_accuracy: 0.8333
# Epoch 99/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.2052 - accuracy: 0.9250 - val_loss: 0.6612 - val_accuracy: 0.8333
# Epoch 100/100
# 39/39 [==============================] - 57s 1s/step - loss: 0.1492 - accuracy: 0.9543 - val_loss: 0.7072 - val_accuracy: 0.8472

# %%
loss, acc = model.evaluate(test_data,verbose = 1)
# Out:
# 20/20 [==============================] - 24s 1s/step - loss: 0.4331 - accuracy: 0.8698

# %%
import seaborn as sns
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob , axis = 1)
true_label = test_data.classes
report = classification_report(true_label,predictions)
print(report)
# Out:
# 20/20 [==============================] - 29s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86       120
#            1       0.79      0.96      0.87        51
#            2       1.00      0.94      0.97        54
#            3       0.83      0.81      0.82        90
#
#     accuracy                           0.87       315
#    macro avg       0.88      0.89      0.88       315
# weighted avg       0.87      0.87      0.87       315

# %%
conf_mat = confusion_matrix(true_label,predictions)
sns.heatmap(conf_mat ,fmt='g',annot = True , cmap='Blues' , xticklabels=test_classes , yticklabels = test_classes,)
plt.xlabel('Predictions')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.xticks(rotation = 45)
plt.show()

# %%
res = results.history
train_acc = res['accuracy']
val_accuracy = res['val_accuracy']
epochs = range(1, len(train_acc) + 1)

line1 = plt.plot(epochs, val_accuracy, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, train_acc, label = 'Training Accuracy')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
res = results.history
train_loss = res['loss']
val_loss = res['val_loss']
epochs = range(1, len(train_loss) + 1)

line1 = plt.plot(epochs, val_loss, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, train_loss, label = 'Training Loss')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob, axis=1)
true_labels = test_data.classes
# Out:
# 20/20 [==============================] - 22s 1s/step

# %%
class_names = list(test_data.class_indices.keys())

# %%
predicted_labels = [class_names[pred] for pred in predictions]
true_labels = [class_names[true] for true in true_labels]

# %%
for i in range(len(predictions)):
    print(f"Gerçek Sınıf: {true_labels[i]}, Tahmin: {predicted_labels[i]}")
# Out:
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: adenocarcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: large.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: normal, Tahmin: adenocarcinoma
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: normal, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: normal, Tahmin: normal
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: large.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: adenocarcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma
# Gerçek Sınıf: squamous.cell.carcinoma, Tahmin: squamous.cell.carcinoma

# %%
from sklearn.metrics import classification_report
print(classification_report(true_labels, predicted_labels))
# Out:
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.89      0.84      0.86       120
#    large.cell.carcinoma       0.79      0.96      0.87        51
#                  normal       1.00      0.94      0.97        54
# squamous.cell.carcinoma       0.83      0.81      0.82        90
#
#                accuracy                           0.87       315
#               macro avg       0.88      0.89      0.88       315
#            weighted avg       0.87      0.87      0.87       315

# %%
images, labels = next(test_data)
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob, axis=1)
# Out:
# 20/20 [==============================] - 21s 1s/step

# %%
class_names = list(test_data.class_indices.keys())

# %%
plt.figure(figsize=(12, 9))
for i in range(15):
    plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].astype('uint8'))
    true_label = class_names[np.argmax(labels[i])]
    predicted_label = class_names[predictions[i]]
    plt.title(f"Gerçek: {true_label}\nTahmin: {predicted_label}")
    plt.axis('off')

plt.show()

# %%
loss, accuracy = model.evaluate(test_data, verbose=1)

print(f"Test Doğruluk Değeri: {accuracy * 100:.2f}%")
# Out:
# 20/20 [==============================] - 23s 1s/step - loss: 0.4331 - accuracy: 0.8698
# Test Doğruluk Değeri: 86.98%
